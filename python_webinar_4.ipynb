# %% [markdown]
#     Contents
#
#
#         Introduction to Python
#         Getting Started with Python
#            Introduction to Google Colab
#         Getting Help
#         Python Variables
#         Type Conversion
#         Python Error - The Art of Debugging
#         Python Constructs
#         Basic Data Structures
#           Set
#           List
#              List Comprehension
#           Tuples and Dictionary
#         Iterables and Iterators
#         Functions and Methods
#         Files
#         Pattern Matching in Python

# %% [markdown]
# Introduction to Python

# %% [markdown]
#           Introduction to Python Programming
#
#                   - Programming
#                   Structured way of Problem-Solving
#
#                   - instruction
#                   Steps/commands to solve the given problem
#
#                   - language
#                   represent or defined through rules
#
#                   - About Python
#                          - created in 1991
#                          - by Guido van Rossum
#
#
#
#                   was bored during a week around Christmas 1989 and started Python as a hobby project "that would keep occupied" for some days
#
#                   Release
#                   Python 0.9.0   - 1991
#                   Python 2.0     - 2000
#                   Python 3.0     - 2008
#                   Python 3.11.2  - 2023 (Feb)
#
#
#                   - python Features
#                          - works on different platform
#                          - easy ( simple synatax, similar to English)
#                          - opensource
#
#
#                   - Application
#
#                          - Automation(repetitive tasks such as)
#                             - Sending mass emails from a list of recipients
#                             - Search for text in a file or across multiple files
#                             - Create, update, move, and rename files and folders
#                             - Send reminder emails and text notifications
#                             - And more!
#                          - Mathematical problem solving
#                          - Pre-processing
#                          - Web development
#                          - Building Machine Learning model
#                          - Data analysis
#                          - Server side programming
#                          - Game development .....
#
#                   - Tools
#                         - Linux (By default Python is installed)
#                         - Windows (Need to Install)
#                         - colab (No need to install, need only gmail account)

# %% [markdown]
# Getting Started with Python

# %% [markdown]
# To check Python Version

# %%
# !python --version

# %%
# !python --version
# Out:
# Python 3.10.11

# %% [markdown]
# ! - is used to execute system commands in colab

# %% [markdown]
# To list out the files and folders in the current location

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# To list of the current location

# %%
# !pwd
# Out:
# /content

# %%
#!pip install package_name
# !pip install wordcloud

# %% [markdown]
# In simple words, ! is used to execute system commands in notebook

# %% [markdown]
#     Getting Started
#                  - Syntax
#                         -Set of rules defined by the programming language.
#                     computer understand exactly what you are trying to say in your code.
#
#                         -If you do not follow these set of rules, you may come across syntax error, and your programme may not work correctly.
#
#                     Examples of syntax errors:
#                     - an extra dot or comma in your code
#                     - a missing semicolon at the end of a set of codes
#                     - Indentation for blocks
#
#
#                     - Comment
#                     used for
#                           documentation
#                           debugging
#
#                     - Indentation
#                     specify the block of code
#
#                     - Continuation of statements

# %% [markdown]
# Google Colab

# %% [markdown]
#     - Google Colab - Product from Google
#     - access through Browser
#     - Need google account and Internet
#     - Free access to GPU ( Limited)
#     - No set-up required
#     - Easy to share and collobrate

# %% [markdown]
# import statement

# %%
#syntax
# import module_name

# %% [markdown]
# Filesystem Operations

# %%
import os

# %%
print(os.getcwd())
# Out:
# /content

# %%
print(os.listdir("/content"))
# Out:
# ['.config', 'sample_data']

# %%
print(os.listdir("sample_data"))
# Out:
# ['README.md', 'anscombe.json', 'california_housing_test.csv', 'mnist_test.csv', 'california_housing_train.csv', 'mnist_train_small.csv']

# %%
print(os.path.isdir("/content/sample_data/california_housing_test.csv")) # try with isfile
# Out:
# False

# %% [markdown]
# To Get Help

# %%
dir(os)

# %%
help(os)

# %%
help()

# %%
help('math')

# %%
dir('math')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %% [markdown]
# Dir and help are two must-know functions in Python. Dir will provide us with a list of methods available on the object of interest while help will inspect a specific method

# %%
name="Manipal"
type(name)
dir('name')

# %%
help('name'.upper)

# %% [markdown]
# len()
# upper()

# %%
name.upper()

# %%
len('name')
# Out:
# 4

# %%
from math import log

# %%
help(log)

# %%
from math import * 
help('math.pow')
# Out:
# Help on built-in function pow in math:
#
# math.pow = pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
from math import * 
help('pow')
# Out:
# Help on built-in function pow in module builtins:
#
# pow(base, exp, mod=None)
#     Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
#     Some types, such as ints, are able to use a more efficient algorithm when
#     invoked using the three argument form.

# %%
from os import listdir

# %%
help(listdir)

# %%
help()

# %%
fname="Manipal"
print(fname)
# Out:
# Manipal

# %%
type(fname)
# Out:
# str

# %%
dir(fname)

# %%
help(isupper)

# %%
help('str')

# %%
print(dir('str'))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# ...

# %%
result=fname.isupper()
print(result)

# %%
wish_list = ['Task1', 'Task2', 'Task3']
result = type(wish_list)
print(result)

# %%
help('print')

# %%
help('list')

# %%
help('help')

# %%
import datetime as dt

# %%
x = dt.datetime.now()

print(x.year)
print(x.strftime("%A"))
# Out:
# 2023
# Friday

# %% [markdown]
# Python variables

# %%
# Variables - container - to store values 
# statements  
a = 10                #numeric value 
marks = 10.5          #float 
course = "MSC"        #string 
img_no= 31+9j         #complex 
flag= True            #Boolean 
webinar=dt.date(2022, 11, 5)

# %% [markdown]
#  Naming Variable and keywords
#
#      - must start with a letter or the underscore character
#      - cannot start with a number
#      - can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#      - are case-sensitive (name,Name and NAME are three different variables)

# %%
import keyword
keyword.kwlist

# %%
# To check the data type 
type(webinar)
# Out:
# datetime.date

# %% [markdown]
# type conversion

# %%
hobbies = input("What is your hobby")
hobbies 
type(hobbies)
# Out:
# What is your hobbyreading
# str

# %%
regno = int(input("Enter reg.no"))
regno 
type(regno)
# Out:
# Enter reg.no123
# int

# %%
name=input("what is your name:")

# get the value from the user 
year=int(input("enter birth year:"))
name="xyz"
year ="23"
# Before coversion
print(type(name))
print(type(year))

# after conversion 
year=int(year)
print(type(year))

# %% [markdown]
#     Data Type	                Syntax
#
#
#     strings	                  str()
#     integer	                  int()
#     floats	                  float()
#     lists	                    list()
#     tuple                     tuple()
#     dict                      dict()
#     set                       set()
#
#
#
#     Note:
#     list() - accepts only one parameter
#     tuple() - accepts either string or list
#     dict() - pair of values, converts tuple of order/list of order
#              key must be unique, otherwise duplicate values get overriden

# %%
wish_list = ['Task1', 'Task2']
type(wish_list)
# Out:
# list

# %%
wish_list1=tuple(wish_list)
type(wish_list1)
# Out:
# tuple

# %%
wish_list = "Task3"
type(wish_list)

# %%
tuple(wish_list)
# Out:
# ('T', 'a', 's', 'k', '3')

# %%
# nested tuple
tup_inp = (('MachineLearning', 12) ,('DataScience', 10), ('Finance',13), ('Finance',12))

# conversion to dictionary
c = dict(tup_inp)

print ("list to dictionary : ",c)
# Out:
# list to dictionary :  {'MachineLearning': 12, 'DataScience': 10, 'Finance': 12}

# %%
# nested list
list_inp = [['MachineLearning', 20] ,['DataScience', 15]]

# conversion to dictionary
d = dict(list_inp)

print ("list to dictionary : ",d)
# Out:
# list to dictionary :  {'MachineLearning': 20, 'DataScience': 15}

# %%
greeting = 'Hello'
set1 = set(greeting)
print(set1)
   

greeting = set(["Hello", "Namaskara", "Namaste"])
print("\nSet with the use of List: ")
print(greeting)
# Out:
# {'l', 'e', 'o', 'H'}
#
# Set with the use of List:
# {'Namaste', 'Namaskara', 'Hello'}

# %%
# To get the values from the user
fname = input("Enter your Name")
print(fname)
# Out:
# Enter your NameKeerthana

# %%
# Python code to convert string to list
  
def Convert(string):
    li = list(string.split(":"))
    return li
  
str1 = "Python:programming"
print(Convert(str1))
# Out:
# ['Python', 'programming']

# %%
fnum =input("Enter your Favorite Number:")
print (fnum)
type(fnum)
fnum=int(fnum)
type(fnum)
# Out:
# Enter your Favorite Number:6
# 6
# int

# %% [markdown]
# TRY

# %%
# Find the data type

# %%
# To get the favorite number from the user  and store in the variable fnum

# %%
# Find the data type

# %%
# convert into int

# %%
# Are you able to print the following? Try it in your IDE. 

01_street = ‘Temple Square’
YEAR = 1995
course_code = "DSE2020"
my-birth-year = 1956

# %%
print("Number Addition")
print("This program asks for three numbers and then outputs the total")
print()
#input function is used to get the value from the user 
# convert the value to intger using int

num1 = int(input("Please enter a number: "))
num2 = int(input("Please enter a second number: "))
num3 = int(input("Please enter a third number: "))
print()
ans = num1 + num2 + num3
print ("Total = ", ans)

# %%
#Find X raised to power N


x=int(input())
n=int(input())
res=pow(x,n)
print(res)

# %% [markdown]
# Error

# %% [markdown]
#       Errors
#
#                 - syntax
#                 - Run Time
#                 - Logical

# %% [markdown]
#     Syntax Error
#
#     Python parser is unable to understand a line of code
#     cause : Due to wrong syntax

# %%
print (Hello World)
# Out:
#   File "<ipython-input-22-f9d093f8741d>", line 1
#     print (Hello World)
#                      ^
# SyntaxError: invalid syntax

# %%
class = "Programming  with Python"

# %%
name = "Manipal

# %%
name = "Manipal'

# %% [markdown]
# Run Time Error

# %%
#Program to explain Runtime Error
a=2
b=3
c=4
d=input("enter a number")
sum=a+b+c+d
print(sum)

# %%
callMe = "Maybe"
print(callme)

# %%
print(1/0)

# %%
print("you cannot add text and numbers" + 12)

# %% [markdown]
# Logic Error

# %%
x = 3
y = 4
average = x + y / 2
print(average)

# Calculate the average of x and y
# Out:
# 5.0

# %% [markdown]
# **COMMENT**

# %% [markdown]
#         Comment
#
#         - Is a programmer-readable explanation of the code of a program.
#
#         Types of Comment
#
#         - Block Comment
#         - Inline Comment
#         - Multi-line Comment

# %%
# Example for Block Comment 
# Block comment consists of series of single line comment
# line -3
# line -4

# %%
# Inline Comment - Example
x= 10  # declare a variable x with value 10

# %% [markdown]
#        Docstring
#
#         Python also has extended documentation capability, called docstrings.
#
#         Docstrings can be one line, or multiline.
#
#         Docstrings are also comments:
#
#         Python uses triple quotes at the beginning and end of the docstring:

# %%
"""
Use * for multiplication of a number
The * is a multiplication operator in Python
To print the value, use the print() function
"""
print(3 * 7)
# Out:
# 21

# %%
print ("hello")

'''
  Multiline comment 
  it is used for 
      - documentation
      - debug the code  

'''
# Out:
# hello
# '\n  Multiline comment \n  it is used for \n      - documentation\n      - debug the code  \n\n'

# %%
'''This is a really long comment that can make
the code look ugly and uncomfortable to read on
a small screen so it needs to be broken into
multi-line strings using double triple-quotes'''
 
print("hello Students")
# Out:
# hello Students

# %%
"""
Use * for multiplication of a number
The * is a multiplication operator in Python
To print the value, use the print() function
"""

print ("Hello")
# Out:
# Hello

# %%
'''
it is called as Docstring. 
it is not ignored by interpreter 
comments are ignored by interpreter 
'''
# Out:
# '\nit is called as Docstring. \nit is not ignored by interpreter \n#comments are ignored by interpreter \n'

# %%
def validate():

  '''
  this is the documentation
  it helps during testing
  '''

  print ("Hello")

# %%
validate()
# Out:
# Hello

# %%
validate.__doc__
# Out:
# '\n  this is the documentation\n  it helps during testing\n  '

# %% [markdown]
#     Escape Sequence

# %%
print(" Python Programming \n is the best" )
# Out:
#  Python Programming
#  is the best

# %% [markdown]
#   Operator
#
#   method vs. functions

# %%
# Slice in Python 
course="DataScience"
course[2]
course[-1]
course[4:]
course[4:6]
# Out:
# 'Sc'

# %% [markdown]
# Mutable vs Immutable

# %%
# Immutable Example
course="Hero"
course[0]
course[0]="Z"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-63cba6aa348d> in <cell line: 4>()
#       2 course="Hero"
#       3 course[0]
# ----> 4 course[0]="Z"
#
# TypeError: 'str' object does not support item assignment

# %%
#Mutable
course=["DataScience","MachineLearning","CyberSecurity","InformationScience"]
course[3]
course[3]="ComputerScience"
course
# Out:
# ['DataScience', 'MachineLearning', 'CyberSecurity', 'ComputerScience']

# %% [markdown]
# string Methods

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Method
txt = "welcome to Python Programming" 
x = txt.split()

print(x)

# %%
# chain of methods 
messy_text = "hI thIs is messy Text"
messy_text.lower().replace(' ','')
# Out:
# 'hithisismessytext'

# %% [markdown]
#     functions

# %%
greet="Hello World"

len(greet)
# Out:
# 11

# %%
counter = 0

for i in course:
  if i==" ":
    continue
  else:
    print(counter, i)
  counter += 1

# %%
# iterable ? 
# string = y or n 
# list 
fruits = ["apple", "banana", "chikoo"]

course="DataScience"
counter = 0

for i in course:
  print(counter, i)
  counter += 1

# %%
# enumerate(iterable, start=0)
course="DataScience"
enumerate(course)

# %%
# convert the generated enumerate object in to tuples
for i in enumerate(course): 
  print (i)

# %%
# convert the generated enumerate object in to list
for i in enumerate(course): 
  output=list(i)
  print (output)

# %%
course = "Data Science"
for i,j in enumerate(course,1):
  print(j,"---->",i)

# %%
n=int(input())
while n!=6:
    if n <= 5 and n >= 1:
        a=int(input())
        b=int(input())
    if n==1:
        print(a+b)
    if n==2:
        print(a-b)
    if n==3:
        print(a*2)
    if n==4:
        print(a//b)
    if n==5:
        print(a%b)
    elif n < 1 or n > 6:
        print("Invalid Operation")
    n=int(input())

# %% [markdown]
# There are two types of type conversion in Python.
#
#
#           Implicit Conversion - automatic type conversion
#           Explicit Conversion - manual type conversion

# %%
int_num = 1232
float_num = 12.23

result= int_num + float_num

# display new value and resulting data type
print("Value:",result)
print("Data Type:",type(result))
# Out:
# Value: 1244.23
# Data Type: <class 'float'>

# %% [markdown]
# It is because Python always converts smaller data types to larger data types to avoid the loss of data.
#
#
# We get TypeError, if we try to add str and int. For example, '12' + 23. Python is not able to use Implicit Conversion in such conditions.
#
# Python has a solution for these types of situations which is known as Explicit Conversion.

# %% [markdown]
#     Basic Patterns
#
#     The power of regular expressions is that they can specify patterns, not just fixed characters. Here are the most basic patterns which match single chars:
#
#     a, X, 9, < -- ordinary characters just match themselves exactly. The meta-characters which do not match themselves because they have special meanings are: . ^ $ * + ? { [ ] \ | ( ) (details below)
#
#
#       . (a period) -- matches any single character except newline '\n'
#
#       \w -- (lowercase w) matches a "word" character: a letter or digit or underscore [a-zA-Z0-9\_]. Note that although "word" is the mnemonic for this, it only matches a single word char, not a whole word. \W (upper case W) matches any non-word character.
#
#       \b -- boundary between word and non-word
#
#       \s -- (lowercase s) matches a single whitespace character -- space, newline, return, tab, form [ \n\r\t\f]. \S (upper case S) matches any non-whitespace character.
#
#       \t, \n, \r -- tab, newline, return
#
#       \d -- decimal digit [0-9] (some older regex utilities do not support but \d, but they all support \w and \s)
#
#       ^ = start, $ = end -- match the start or end of the string
#
#       \ -- inhibit the "specialness" of a character. So, for example, use \. to match a period or \\ to match a slash. If you are unsure if a character has special meaning, such as @, you can put a slash in front of it, \@, to make sure it is treated just as a character.

# %%
import re

## Search for pattern 'hello' in string 'hello world'.
## All of the pattern must match, but it may appear anywhere.
## On success, match.group() is matched text.

match = re.search('ll', 'Hello world')
match.group()
# Out:
# 'll'

# %%
match = re.search('Hello', 'Hello World')
print(match)
# Out:
# <re.Match object; span=(0, 5), match='Hello'>

# %%
## . = any char but \n
match = re.search('He..o', 'Hello')
match
# Out:
# <re.Match object; span=(0, 5), match='Hello'>

# %%
## \d = digit char, \w = word char
match = re.search('\d\d\d', 'p123g')
extract=match.group()
print(extract)
# Out:
# 123
